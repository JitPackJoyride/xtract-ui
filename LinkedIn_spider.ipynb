# %%
import parameters

import csv
import time
# import web driver
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def append_to_csv(items, file):
    with open(file, 'a', newline="", encoding="utf-8") as fp:
        writer = csv.writer(fp)
        for item in items:
            writer.writerow(item)

def save_to_csv(items, file):
    with open(file, "w+", newline="", encoding="utf-8") as fp:
        writer = csv.writer(fp)
        for item in items:
            writer.writerow(item)

# specifies the path to the chromedriver.exe
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(10)

# driver.get method() will navigate to a page given by the URL address
driver.get('https://www.linkedin.com')

# locate email form by_class_name
username = driver.find_element_by_css_selector('.input:nth-child(1) .input__field--with-label')

# send_keys() to simulate key strokes
username.send_keys(parameters.linkedin_username)

time.sleep(1)

# locate password form by_class_name
password = driver.find_element_by_css_selector('.input+ .input .input__field--with-label')

# send_keys() to simulate key strokes
password.send_keys(parameters.linkedin_password)

time.sleep(1)

# locate submit button by_class_name
log_in_button = driver.find_element_by_css_selector('.sign-in-form__submit-btn')

# .click() to mimic button click
log_in_button.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import parameters
from lxml import html

data = [['Name', 'URL', 'Industry', 'Description']]
save_to_csv(data, parameters.file_name)

for query in parameters.search_query:
    # driver.get method() will navigate to a page given by the URL address
    driver.get('https://www.google.com')

    # locate search form by_name
    search_query = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')

    # send_keys() to simulate the search text key strokes
    search_query.send_keys(query)

    time.sleep(0.5)

    # .send_keys() to simulate the return key 
    search_query.send_keys(Keys.RETURN)
    time.sleep(2)



    all_linkedin_urls = []

    for i in range(5):
        if i != 0:
            driver.get(next_page)
        linkedin_urls = driver.find_elements_by_xpath('//div[@class="g"]//div[@class="r"]/a')
        linkedin_urls = [url.get_attribute("href") for url in linkedin_urls]
        time.sleep(0.5)

        for url in linkedin_urls:
            all_linkedin_urls.append(url)

        tree = html.fromstring(driver.page_source)
        
        if tree.xpath('//div[@role="navigation"]//a[@class="pn"]'):
            next_page = driver.find_elements_by_xpath('//div[@role="navigation"]//a[@class="pn"]')
            next_page = [page.get_attribute("href") for page in next_page]
            next_page = next_page[-1]
        else:
            break

    for url in all_linkedin_urls:
        print(url)
    #driver.quit()
    time.sleep(0.5)



    new_data = []
    for i in range(len(all_linkedin_urls)):
        datum = []
        driver.get(all_linkedin_urls[i] + "/about/")
        time.sleep(1)
    
        tree = html.fromstring(driver.page_source)

        if tree.xpath('//h1[@class="org-top-card-summary__title t-24 t-black truncate"]'):
            Name = driver.find_element_by_xpath('//h1[@class="org-top-card-summary__title t-24 t-black truncate"]').get_attribute("title")
        else:
            Name = "N/A"
        datum.append(Name)

        if tree.xpath('//dd[@class="org-page-details__definition-text t-14 t-black--light t-normal"]/a'):
            URL = driver.find_element_by_xpath('//dd[@class="org-page-details__definition-text t-14 t-black--light t-normal"]/a').get_attribute("href")
        elif tree.xpath('//div[@class="org-top-card-primary-actions__inner"]/a'):
            URL = driver.find_element_by_xpath('//div[@class="org-top-card-primary-actions__inner"]/a').get_attribute("href")
        else:
            URL = "N/A"
        datum.append(URL)
    
        if tree.xpath('//div[@class="org-top-card-summary__info-item org-top-card-summary__industry"]'):
            Industry = driver.find_element_by_xpath('//div[@class="org-top-card-summary__info-item org-top-card-summary__industry"]').text
        else:
            Industry = "N/A"
        datum.append(Industry)

        if tree.xpath('//p[@class="break-words white-space-pre-wrap mb5 t-14 t-black--light t-normal"]'):
            Description = driver.find_element_by_xpath('//p[@class="break-words white-space-pre-wrap mb5 t-14 t-black--light t-normal"]').text
        else:
            Description = "N/A"
        datum.append(Description)
    
        new_data.append(datum)

    append_to_csv(new_data, parameters.file_name)
# Out:
# https://www.linkedin.com/company/art-loss-register
# https://www.linkedin.com/company/pawnbroker-gold
# https://www.linkedin.com/company/prestige-pawnbrokers
# https://www.linkedin.com/company/alltirbes-native-american-art-llc
# https://sv.linkedin.com/company/pawn1st-pawn-&-title-loan-center
# https://translate.google.com/translate?hl=en&sl=es&u=https://sv.linkedin.com/company/pawn1st-pawn-%26-title-loan-center&prev=search
# https://www.linkedin.com/company/the-logistics-company
# https://work.chron.com/average-salary-logistics-manager-4231.html
# https://www.monster.co.uk/advertise-a-job/hr-resources/hr-strategies/job-descriptions/logistics-coordinator-job-description/
# http://www.v-logistics.co.uk/logistics/outbound-vs-inbound-logistics/
# https://cscmp.org/CSCMP/Educate/SCM_Definitions_and_Glossary_of_Terms/CSCMP/Educate/SCM_Definitions_and_Glossary_of_Terms.aspx?hkey=60879588-f65f-4ab5-8c4b-6878815ef921
# https://www.linkedin.com/company/logistics-in-vision-enterprises-inc
# https://www.linkedin.com/company/st-logistics
# https://www.linkedin.com/company/logistics-&-distribution-srvs-corp
# https://www.linkedin.com/company/show-me-logistics
# https://www.linkedin.com/company/transgroup-global-logistics
# https://www.linkedin.com/company/securegloballogistics
# https://www.linkedin.com/company/jetft
# https://www.linkedin.com/company/anthym
# https://www.linkedin.com/company/gallega-global-logistics
# https://www.linkedin.com/company/scan-global-logistics
# https://www.linkedin.com/company/bhc-logistics-supply-company
# https://www.linkedin.com/company/fastmore-logistics
# https://www.linkedin.com/company/transgroup-global-logistics
# https://www.linkedin.com/company/etmam
# https://www.linkedin.com/company/jetft
# https://www.linkedin.com/company/pillow-logistics
# https://www.linkedin.com/company/logistics-in-motion-inc
# https://www.linkedin.com/company/leaflogistics
# https://www.linkedin.com/company/access-logistics
# https://www.linkedin.com/company/firstgold
# https://www.linkedin.com/company/taifex
# https://www.linkedin.com/company/global-precious-metals
# https://uy.linkedin.com/company/igrglobal
# https://translate.google.com/translate?hl=en&sl=es&u=https://uy.linkedin.com/company/igrglobal&prev=search
# https://cn.linkedin.com/company/gold-corporation---the-perth-mint
# https://translate.google.com/translate?hl=en&sl=zh-CN&u=https://cn.linkedin.com/company/gold-corporation---the-perth-mint&prev=search
# https://www.linkedin.com/company/top-harvest-limited
# https://www.linkedin.com/company/hooktangaza
# https://www.linkedin.com/company/exceptio
# https://lt.linkedin.com/company/goldexapp
# https://me.linkedin.com/company/bullion-capital
# https://www.linkedin.com/company/es-groups-inc
# https://www.linkedin.com/company/francoise-paviot
# https://ca.linkedin.com/company/ausukchamber
# https://www.linkedin.com/company/anbud365
# https://translate.google.com/translate?hl=en&sl=no&u=https://www.linkedin.com/company/anbud365&prev=search
# https://cy.linkedin.com/company/premiapartners
# https://bd.linkedin.com/company/es-groups-inc
# https://pl.linkedin.com/company/top-harvest-limited?trk=similar-companies_org_title
# https://translate.google.com/translate?hl=en&sl=pl&u=https://pl.linkedin.com/company/top-harvest-limited%3Ftrk%3Dsimilar-companies_org_title&prev=search
# https://lu.linkedin.com/company/bullion-capital
# https://translate.google.com/translate?hl=en&sl=fr&u=https://lu.linkedin.com/company/bullion-capital&prev=search
# https://fr.linkedin.com/company/activedocs?trk=extra_biz_viewers_viewed
# https://www.linkedin.com/company/max-money
# https://www.linkedin.com/company/vowpay
# https://www.linkedin.com/company/moneyexchange
# https://www.linkedin.com/company/linkedin.com-rrsbforex
# https://www.linkedin.com/company/remitone-ltd
# https://www.linkedin.com/company/cysglobalremit
# https://www.linkedin.com/company/pakistan-currency-exchange-pvt-ltd
# https://www.linkedin.com/company/al-ahalia-exchange
# https://www.linkedin.com/company/ravi-exchange-company-pvt-ltd
# https://www.linkedin.com/company/orient-exchange-financial-services-p-ltd
# https://www.linkedin.com/company/acemoneytransfer
# https://www.linkedin.com/company/money-remittance-worldwide-limited
# https://www.linkedin.com/company/xpress-money-services-ltd
# https://www.linkedin.com/company/aa-exchange-company-pvt-ltd-
# https://www.linkedin.com/company/bfcforex
# https://www.linkedin.com/company/sadiq-exchange-company-private-limited
# https://www.linkedin.com/company/wall-street-finance-limited
# https://www.linkedin.com/company/whitepaperforex
# https://www.linkedin.com/company/bahrain-financing-company
# https://br.linkedin.com/company/max-money
# https://translate.google.com/translate?hl=en&sl=pt&u=https://br.linkedin.com/company/max-money&prev=search
# https://hk.linkedin.com/company/private-lender-link
# https://www.linkedin.com/company/the-money-lenders
# https://www.linkedin.com/company/hard-money-lenders
# https://www.linkedin.com/company/private-money-lenders-inc
# https://www.linkedin.com/company/nlds-corp
# https://www.linkedin.com/company/accredit-money-lender
# https://hk.linkedin.com/company/privatelenderexpo
# https://www.linkedin.com/company/private-lender-inc
# https://www.linkedin.com/company/online-hard-money-lender
# https://www.linkedin.com/company/money-lenders-plus
# https://www.linkedin.com/company/private-lending-group
# https://www.linkedin.com/company/hard-money-loans-lenders
# https://www.linkedin.com/company/private-lender-nexus
# https://www.linkedin.com/company/california-private-money-lenders
# https://www.linkedin.com/company/lantzman-lending
# https://www.linkedin.com/company/cornerstone-company-private-money-lending
# https://www.linkedin.com/company/star-capital-money-lending-ltd
# https://www.linkedin.com/company/carolina-hard-money
# https://www.linkedin.com/company/inbound-loans
# https://www.linkedin.com/company/tidal-loans-htx
# https://www.linkedin.com/company/gulf-court-hotel-business-bay
# https://www.linkedin.com/company/lucky-ruby-casino-&-resort
# https://www.linkedin.com/company/green-building-council-finland
# https://translate.google.com/translate?hl=en&sl=fi&u=https://www.linkedin.com/company/green-building-council-finland&prev=search
# https://www.linkedin.com/company/hoogheemraadschap-van-delfland
# https://translate.google.com/translate?hl=en&sl=nl&u=https://www.linkedin.com/company/hoogheemraadschap-van-delfland&prev=search
# https://www.linkedin.com/company/lidl-finland
# https://translate.google.com/translate?hl=en&sl=fi&u=https://www.linkedin.com/company/lidl-finland&prev=search
# https://www.linkedin.com/company/hotel-gaythering
# https://lu.linkedin.com/company/caiooulu
# https://translate.google.com/translate?hl=en&sl=fr&u=https://lu.linkedin.com/company/caiooulu&prev=search
# https://www.linkedin.com/company/permanser-consulting
# https://www.linkedin.com/company/can-textile-apparel-manufacturer
# https://www.linkedin.com/company/spin360
# https://www.linkedin.com/company/textile-and-fashion-industry-training-centre
# https://au.linkedin.com/company/immagointernational
# https://www.linkedin.com/company/friendly-factories
# https://www.linkedin.com/company/ry-international
# https://www.linkedin.com/company/flokser-group
# https://www.linkedin.com/company/active-apparel-recruitment
# https://www.linkedin.com/company/ethical-clothing-australia
# https://www.linkedin.com/company/micar-software-ltd
# https://www.linkedin.com/company/flokser-group
# https://www.linkedin.com/company/active-apparel-recruitment
# https://be.linkedin.com/company/sustainable-textile-solutions-sts-
# https://hk.linkedin.com/company/mediatexinternational
# https://www.linkedin.com/company/better-earth-textile-recycling-inc-
# https://www.linkedin.com/company/united-clothing
# https://www.linkedin.com/company/andinatextilmexico
# https://www.linkedin.com/company/u&i-recruitment-ltd
# https://www.linkedin.com/company/apparel-impact-institute

# %%
driver.quit()
